# %%
A={2:"Tashfeen"}
print(A)
print(A[2])
# Out:
# {2: 'Tashfeen'}
# Tashfeen

# %%
A=['TASHFEEN','MAWIYA','TAMEEM']
print(A[1])
# Out:
# MAWIYA

# %%
A={1,2,2,3,5,'@','MAWIYA'}
print(A)
# Out:
# {1, 2, 3, 5, '@', 'MAWIYA'}
